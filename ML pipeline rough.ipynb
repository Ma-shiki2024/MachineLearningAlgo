# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px
from sqlalchemy import create_engine
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from tqdm import tqdm

# %%
# Define the connection parameters
host = 'localhost'
dbname = 'StarsGalaxiesQuasars'
user = 'postgres'
password = '121792'
port = '5432'

# Create the connection string
connection = f'postgresql://{user}:{password}@{host}:{port}/{dbname}'

# Create a connection engine using SQLAlchemy
engine = create_engine(connection)

# %%
# Write a SQL query to join the observation and classification tables
join_query = """
SELECT o.*, c.class
FROM observation o
JOIN classification c ON o.classid = c.classid;
"""

# %%
# Load the data into a Pandas DataFrame
database_df = pd.read_sql(join_query, engine)

# %%
# Check DataFrame
database_df.head()
# Out:
#    observationid  classid                objid          ra       dec  \
# 0              1        1  1237650000000000000  183.531326  0.089693
# 1              2        1  1237650000000000000  183.598370  0.135285
# 2              3        2  1237650000000000000  183.680207  0.126185
# 3              4        1  1237650000000000000  183.870529  0.049911
# 4              5        1  1237650000000000000  183.883288  0.102557
#
#           u         g         r         i         z  redshift  run  rerun  \
# 0  19.47406  17.04240  15.94699  15.50342  15.22531     752.0  301      4
# 1  18.66280  17.21449  16.67637  16.48922  16.39150     752.0  301      4
# 2  19.38298  18.19169  17.47428  17.08732  16.80125     752.0  301      4
# 3  17.76536  16.60272  16.16116  15.98233  15.90438     752.0  301      4
# 4  17.55025  16.26342  16.43869  16.55492  16.61326     752.0  301      4
#
#    camcol         field     specobjid  plate    mjd  fiberid   class
# 0     267  3.722360e+18     -8.96e-06   3306  54922      491    STAR
# 1     267  3.638140e+17     -5.49e-05    323  51615      541    STAR
# 2     268  3.232740e+17     0.1231112    287  52023      513  GALAXY
# 3     269  3.722370e+18  -0.000110616   3306  54922      510    STAR
# 4     269  3.722370e+18   0.000590357   3306  54922      512    STAR

# %%
# Count plot of different classes
plt.figure(figsize=(8, 5))
sns.countplot(data=database_df, x='class', palette='viridis')
plt.title("Distribution of Object Classes")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# print(f"Class distribution:\n{y.value_counts()}")
# Out:
# C:\Users\Ian O'Connor\AppData\Local\Temp\ipykernel_26532\2057781444.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Set plot style
sns.set_style("whitegrid")

# Density plots for numerical columns
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
features = ['ra', 'dec', 'u', 'g', 'r', 'redshift']
for i, feature in enumerate(features):
    row, col = divmod(i, 3)
    sns.kdeplot(data=database_df, x=feature, hue='class', fill=True, ax=axes[row, col], alpha=0.5)
    axes[row, col].set_title(f"Density Plot of {feature}")

plt.tight_layout()
plt.show()

# %%
# 3D Scatter Plot of RA, DEC, and Redshift
fig = px.scatter_3d(database_df, x='ra', y='dec', z='redshift', color='class', opacity=0.7)
fig.update_layout(title="3D Scatter Plot of RA, DEC, and Redshift")
fig.show()

# %%
# Drop non-numeric columns except 'class'
ml = database_df.drop(columns=['observationid', 'classid', 'objid', 'specobjid', 'run', 'rerun', 'camcol', 'field', 'fiberid', 'plate', 'mjd', 'ra', 'dec', 'redshift'])

# %%
# Check for data leakage: Look for strong correlations between features and target class
# Select only the numeric columns for correlation analysis
numeric_df = ml.select_dtypes(include=[np.number])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.tight_layout()
plt.show()

# %%
# Encode categorical target variable
le = LabelEncoder()
ml['class'] = le.fit_transform(ml['class'])

# %%
# Separate the data into labels and features
y = database_df['class'].map({'STAR': 0, 'GALAXY': 1, 'QSO': 2})
X = ml.drop(columns=['class'])

# %%
# Split the data using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Initialize StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert back to DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

# %%
# Initialize and train the Gradient Boosting model
model = GradientBoostingClassifier(n_estimators=100, random_state=42)
model.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
# Make predictions
y_pred_gb = model.predict(X_test_scaled)

# %%
# Evaluate the model against the true class labels
print(f"Gradient Boosting Accuracy: {accuracy_score(y_test, y_pred_gb):.2f}")
print(classification_report(y_test, y_pred_gb, target_names=['star', 'galaxy', 'qso']))
# Out:
# Gradient Boosting Accuracy: 0.88
#               precision    recall  f1-score   support
#
#         star       0.84      0.90      0.87       832
#       galaxy       0.92      0.87      0.89       999
#          qso       0.90      0.85      0.87       169
#
#     accuracy                           0.88      2000
#    macro avg       0.89      0.87      0.88      2000
# weighted avg       0.88      0.88      0.88      2000

# %%
# Define hyperparameter tuning grid
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of boosting stages
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Step size shrinkage
    'max_depth': [3, 5, 7],  # Maximum depth of individual trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum samples required at a leaf node
    'subsample': [0.7, 0.8, 0.9, 1.0]  # Fraction of samples used for fitting individual trees
}

# Initialize the Gradient Boosting model
gb = GradientBoostingClassifier(random_state=42)

# %%
# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(gb, param_grid, n_iter=4, cv=3, scoring='accuracy', n_jobs=-1, verbose=1, random_state=634)

def fit_with_progress_bar(random_search, X_train, y_train):
    with tqdm(total=random_search.n_iter, desc="Progress", unit="trial") as pbar:
        best_score = -np.inf
        best_params = None
        
        params = random_search.param_distributions
        for _ in range(random_search.n_iter):
            random_params = {key: np.random.choice(val) if isinstance(val, list) else val for key, val in params.items()}
            gb.set_params(**random_params)
            
            cv = StratifiedKFold(n_splits=random_search.cv, shuffle=True, random_state=1)
            cv_scores = [gb.fit(X_train.iloc[train_idx], y_train.iloc[train_idx]).score(X_train.iloc[test_idx], y_train.iloc[test_idx]) for train_idx, test_idx in cv.split(X_train, y_train)]
            
            mean_score = np.mean(cv_scores)
            if mean_score > best_score:
                best_score = mean_score
                best_params = random_params
            
            pbar.update(1)
        
        return best_params, best_score

# %%
# Print best hyperparameters
best_params, best_score = fit_with_progress_bar(random_search, X_train_scaled, y_train)
print("\nBest Gradient Boosting Parameters:", best_params)
print("\nBest Score:", best_score)
# Out:
# Progress: 100%|██████████| 4/4 [01:25<00:00, 21.31s/trial]
# Best Gradient Boosting Parameters: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
#
# Best Score: 0.9303743258649307

# %%
# Train final model using the best found hyperparameters
best_gb = GradientBoostingClassifier(**best_params, random_state=42)
best_gb.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(max_depth=7, min_samples_leaf=2, n_estimators=200,
#                            random_state=42, subsample=0.9)

# %%
# Make predictions
y_pred_best_gb = best_gb.predict(X_test_scaled)

# %%
# Evaluate the optimized model
print(f"Optimized Gradient Boosting Accuracy: {accuracy_score(y_test, y_pred_best_gb):.2f}")
print(classification_report(y_test, y_pred_best_gb, target_names=['star', 'galaxy', 'qso']))
# Out:
# Optimized Gradient Boosting Accuracy: 0.94
#               precision    recall  f1-score   support
#
#         star       0.92      0.96      0.94       832
#       galaxy       0.96      0.93      0.94       999
#          qso       0.90      0.89      0.90       169
#
#     accuracy                           0.94      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.94      0.94      0.94      2000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_best_gb)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Perform cross-validation on the best Gradient Boosting model
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(best_gb, X_train_scaled, y_train, cv=cv, scoring='accuracy', n_jobs=-1)

print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {cv_scores.mean():.4f}")
# Out:
# Cross-validation scores: [0.93     0.931875 0.94625  0.938125 0.943125]
# Mean cross-validation score: 0.9379

# %%
importances = best_gb.feature_importances_
feature_names = X_train.columns

# Sort feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 6))
sns.barplot(x=importances[sorted_indices][:10], y=[feature_names[i] for i in sorted_indices[:10]], palette="viridis")
plt.xlabel("Feature Importance Score")
plt.ylabel("Feature")
plt.title("Top 10 Important Features in Gradient Boosting")
plt.show()
# Out:
# C:\Users\Ian O'Connor\AppData\Local\Temp\ipykernel_26532\1475929309.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# Apply PCA for visualization
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
# Initialize Gradient Boosting Classifier with valid parameters
gb_model_pca = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=100)

# Train the model
gb_model_pca.fit(X_train_pca, y_train)

# Make predictions
y_pred_pca = gb_model_pca.predict(X_test_pca)

# %%
# Visualize PCA-transformed data
hue_labels = le.inverse_transform(y_test) if hasattr(le, "classes_") else y_test
sns.scatterplot(x=X_test_pca[:, 0], y=X_test_pca[:, 1], hue=hue_labels, alpha=0.6)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Projection of Data")
plt.show()

# %%
# Get feature importance in PCA
components_df = pd.DataFrame(pca.components_, columns=X_train.columns, index=[f'PC{i+1}' for i in range(pca.n_components_)])

# Plot the contributions of original features to the first two principal components
plt.figure(figsize=(10, 6))
sns.heatmap(components_df, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
plt.title("Feature Contributions to Principal Components")
plt.xlabel("Original Features")
plt.ylabel("Principal Components")
plt.show()

# %%
pca_full = PCA().fit(X_train_scaled)
cumulative_variance = np.cumsum(pca_full.explained_variance_ratio_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--', color='teal')
plt.axhline(y=0.95, color='r', linestyle='-')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Number of Components Needed for 95% Variance")
plt.show()

# Print the number of components required for 95% variance
n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Number of principal components required for 95% variance: {n_components_95}")
# Out:
# Number of principal components required for 95% variance: 2

# %%
# Get explained variance ratio
explained_variance = pca.explained_variance_ratio_

# Plot explained variance
plt.figure(figsize=(8, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance * 100, color='teal', alpha=0.7)
plt.xlabel("Principal Component")
plt.ylabel("Variance Explained (%)")
plt.title("Explained Variance by Principal Components")
plt.show()

# %%
# Evaluate PCA-based SVM
print("\nGradient Boosting Model with PCA Classification Report:")
print(classification_report(y_test, y_pred_pca, target_names=['star', 'galaxy', 'qso']))

# Train SVM on full dataset (without PCA) for comparison
gb_model_full = SGDClassifier(loss='hinge', max_iter=10000, tol=1e-3, random_state=100)
gb_model_full.fit(X_train_scaled, y_train)
y_pred_full = gb_model_full.predict(X_test_scaled)

# Evaluate SVM without PCA
print("\nSVM without PCA Classification Report:")
print(classification_report(y_test, y_pred_full, target_names=['star', 'galaxy', 'qso']))
# Out:
# Gradient Boosting Model with PCA Classification Report:
#               precision    recall  f1-score   support
#
#         star       0.71      0.70      0.71       832
#       galaxy       0.78      0.79      0.78       999
#          qso       0.81      0.82      0.81       169
#
#     accuracy                           0.75      2000
#    macro avg       0.77      0.77      0.77      2000
# weighted avg       0.75      0.75      0.75      2000
#
#
# SVM without PCA Classification Report:
#               precision    recall  f1-score   support
#
#         star       0.88      0.96      0.92       832
#       galaxy       0.95      0.92      0.94       999
#          qso       0.96      0.71      0.82       169
#
#     accuracy                           0.92      2000
#    macro avg       0.93      0.86      0.89      2000
# weighted avg       0.92      0.92      0.92      2000

# %%
# Train Random Forest Model
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1, verbose=2)
rf.fit(X_train_scaled, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.1s
# building tree 1 of 100building tree 2 of 100
#
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.4s finished
# RandomForestClassifier(n_jobs=-1, random_state=42, verbose=2)

# %%
# Predictions
y_pred_rf = rf.predict(X_test_scaled)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
# Evaluate model performance
print(f"Random Forest Model Accuracy: {accuracy_score(y_test, y_pred_rf):.2f}")
print(f"\nRandom Forest Model Report:\n{classification_report(y_test, y_pred_rf, target_names=['star', 'galaxy', 'qso'])}")
# Out:
# Random Forest Model Accuracy: 0.94
#
# Random Forest Model Report:
#               precision    recall  f1-score   support
#
#         star       0.92      0.95      0.94       832
#       galaxy       0.96      0.93      0.94       999
#          qso       0.89      0.89      0.89       169
#
#     accuracy                           0.94      2000
#    macro avg       0.92      0.93      0.92      2000
# weighted avg       0.94      0.94      0.94      2000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Feature Importance Visualization
feat_importances = pd.Series(rf.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh', figsize=(10, 6), color='teal')
plt.title("Top 10 Feature Importances - Random Forest")
plt.show()

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
logistic_model = LogisticRegression(random_state=12, max_iter=100)

# Fit the model using scaled training data
logistic_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=12)

# %%
# Make a prediction using the testing data
y_pred_lr = logistic_model.predict(X_test_scaled)

# %%
# Print the classification report for the model
print(f"Logistic Regression Accuracy: {accuracy_score(y_test, y_pred_lr):.4f}")
print(f"\nLogistic Regression Model Report:\n{classification_report(y_test, y_pred_lr, target_names=['star', 'galaxy', 'qso'])}")
# Out:
# Logistic Regression Accuracy: 0.9350
#
# Logistic Regression Model Report:
#               precision    recall  f1-score   support
#
#         star       0.91      0.96      0.93       832
#       galaxy       0.96      0.92      0.94       999
#          qso       0.93      0.90      0.92       169
#
#     accuracy                           0.94      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.94      0.94      0.94      2000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Initialize the model
svm_model = SGDClassifier(loss='hinge', random_state=100, max_iter=1, tol=None)
n_epochs = 100

# %%
# Define class labels outside the loop
classes = np.unique(y)

print("\nTraining SVM with SGD:")
for epoch in tqdm(range(n_epochs), desc="Epoch Progress"):
    svm_model.partial_fit(X_train_scaled, y_train, classes=classes)
# Out:
# Training SVM with SGD:
# Epoch Progress: 100%|██████████| 100/100 [00:00<00:00, 149.37it/s]

# %%
# Make predictions
y_pred_svm = svm_model.predict(X_test_scaled)

# %%
# Evaluate the SVM model
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("\nClassification Report:\n", classification_report(y_test, y_pred_svm, target_names=['star', 'galaxy', 'qso']))
# Out:
# Accuracy: 0.9385
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         star       0.92      0.97      0.94       832
#       galaxy       0.95      0.94      0.95       999
#          qso       0.96      0.79      0.86       169
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.90      0.92      2000
# weighted avg       0.94      0.94      0.94      2000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_svm)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Define the Hyperparameter Tuning grid for SVM
param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf', 'poly']}
svc = SVC()

# %%
# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(svc, param_grid, n_iter=4, cv=3, scoring='accuracy', n_jobs=-1, verbose=1, random_state=634)

def fit_with_progress_bar(random_search, X_train, y_train):
    with tqdm(total=random_search.n_iter, desc="Progress", unit="trial") as pbar:
        best_score = -np.inf
        best_params = None
        
        params = random_search.param_distributions
        for _ in range(random_search.n_iter):
            random_params = {key: np.random.choice(val) if isinstance(val, list) else val for key, val in params.items()}
            svc.set_params(**random_params)
            
            cv = StratifiedKFold(n_splits=random_search.cv, shuffle=True, random_state=1)
            cv_scores = [svc.fit(X_train.iloc[train_idx], y_train.iloc[train_idx]).score(X_train.iloc[test_idx], y_train.iloc[test_idx]) for train_idx, test_idx in cv.split(X_train, y_train)]
            
            mean_score = np.mean(cv_scores)
            if mean_score > best_score:
                best_score = mean_score
                best_params = random_params
            
            pbar.update(1)
        
        return best_params, best_score

# %%
best_params, best_score = fit_with_progress_bar(random_search, X_train_scaled, y_train)
print("\nBest SVM Parameters:", best_params)
print("\nBest Score:", best_score)
# Out:
# Progress: 100%|██████████| 4/4 [00:07<00:00,  1.78s/trial]
# Best SVM Parameters: {'C': 10.0, 'kernel': 'rbf'}
#
# Best Score: 0.9558748892322443

# %%
# Train with linear kernel model
svm_linear = SVC(kernel='linear', random_state=42)
svm_linear.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Predictions
y_pred_svm_linear = svm_linear.predict(X_test_scaled)

# %%
# Evaluate the linear Kernel Model
print("Linear Kernel Classification Report:")
print(classification_report(y_test, y_pred_svm_linear, target_names=['star', 'galaxy', 'qso']))
print("Accuracy (linear Kernel):", accuracy_score(y_test, y_pred_svm))
# Out:
# Linear Kernel Classification Report:
#               precision    recall  f1-score   support
#
#         star       0.92      0.97      0.95       832
#       galaxy       0.98      0.94      0.96       999
#          qso       0.91      0.88      0.89       169
#
#     accuracy                           0.95      2000
#    macro avg       0.94      0.93      0.93      2000
# weighted avg       0.95      0.95      0.95      2000
#
# Accuracy (linear Kernel): 0.9385

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_svm_linear)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Train with rbf kernel model
svm_rbf = SVC(kernel='rbf', random_state=42)
svm_rbf.fit(X_train_scaled, y_train)
# Out:
# SVC(random_state=42)

# %%
# Predictions
y_pred_svm_rbf = svm_rbf.predict(X_test_scaled)

# %%
# Evaluate the linear Kernel Model
print("Linear Kernel Classification Report:")
print(classification_report(y_test, y_pred_svm_rbf, target_names=['star', 'galaxy', 'qso']))
print("Accuracy (linear Kernel):", accuracy_score(y_test, y_pred_svm))
# Out:
# Linear Kernel Classification Report:
#               precision    recall  f1-score   support
#
#         star       0.90      0.97      0.94       832
#       galaxy       0.98      0.92      0.94       999
#          qso       0.93      0.91      0.92       169
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.93      0.93      2000
# weighted avg       0.94      0.94      0.94      2000
#
# Accuracy (linear Kernel): 0.9385

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_svm_rbf)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Use the best parameters from RandomizedSearchCV
best_svc = SVC(C=best_params['C'], kernel=best_params['kernel'], random_state=42)

# Perform cross-validation
cv_scores = cross_val_score(best_svc, X_train_scaled, y_train, cv=StratifiedKFold(n_splits=5), n_jobs=-1)

print(f"Cross-validation scores: \n{cv_scores}")
print(f"\nMean cross-validation score: \n{cv_scores.mean():.4f}")
# Out:
# Cross-validation scores:
# [0.95375  0.955625 0.956875 0.955625 0.96375 ]
#
# Mean cross-validation score:
# 0.9571

# %%
# Apply PCA for visualization
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
svm_model_pca = SGDClassifier(loss='hinge', max_iter=10000, tol=1e-3, verbose=1, random_state=100)
svm_model_pca.fit(X_train_pca, y_train)
y_pred_pca = svm_model_pca.predict(X_test_pca)
# Out:
# -- Epoch 1
# Norm: 8.01, NNZs: 2, Bias: 2.114924, T: 8000, Avg. loss: 3.929585
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 4.89, NNZs: 2, Bias: 1.462426, T: 16000, Avg. loss: 1.628302
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 2.23, NNZs: 2, Bias: -0.728570, T: 24000, Avg. loss: 1.253217
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 1.12, NNZs: 2, Bias: -0.643289, T: 32000, Avg. loss: 1.080920
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 2.10, NNZs: 2, Bias: -0.590026, T: 40000, Avg. loss: 0.991662
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2.44, NNZs: 2, Bias: -0.344371, T: 48000, Avg. loss: 0.932212
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 1.29, NNZs: 2, Bias: -0.516494, T: 56000, Avg. loss: 0.910247
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 1.86, NNZs: 2, Bias: -0.338096, T: 64000, Avg. loss: 0.880143
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 1.11, NNZs: 2, Bias: -0.885222, T: 72000, Avg. loss: 0.848868
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 1.47, NNZs: 2, Bias: -0.459605, T: 80000, Avg. loss: 0.825389
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 1.99, NNZs: 2, Bias: 0.226627, T: 88000, Avg. loss: 0.825173
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 1.34, NNZs: 2, Bias: -0.641224, T: 96000, Avg. loss: 0.812020
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 1.48, NNZs: 2, Bias: 0.241205, T: 104000, Avg. loss: 0.787758
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 1.18, NNZs: 2, Bias: -0.329055, T: 112000, Avg. loss: 0.797705
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 1.63, NNZs: 2, Bias: -0.162463, T: 120000, Avg. loss: 0.785126
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 1.37, NNZs: 2, Bias: 0.292104, T: 128000, Avg. loss: 0.785792
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 1.39, NNZs: 2, Bias: 0.037199, T: 136000, Avg. loss: 0.779742
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 1.60, NNZs: 2, Bias: -0.051647, T: 144000, Avg. loss: 0.769714
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 1.24, NNZs: 2, Bias: 0.065501, T: 152000, Avg. loss: 0.763065
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 1.47, NNZs: 2, Bias: -0.015560, T: 160000, Avg. loss: 0.764543
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 1.35, NNZs: 2, Bias: -0.385659, T: 168000, Avg. loss: 0.757767
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 1.16, NNZs: 2, Bias: -0.044026, T: 176000, Avg. loss: 0.761508
# Total training time: 0.01 seconds.
# -- Epoch 23
# Norm: 1.20, NNZs: 2, Bias: -0.217780, T: 184000, Avg. loss: 0.754281
# Total training time: 0.01 seconds.
# -- Epoch 24
# Norm: 1.26, NNZs: 2, Bias: -0.221895, T: 192000, Avg. loss: 0.749696
# Total training time: 0.01 seconds.
# -- Epoch 25
# Norm: 1.50, NNZs: 2, Bias: 0.121675, T: 200000, Avg. loss: 0.751585
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 1.48, NNZs: 2, Bias: 0.247632, T: 208000, Avg. loss: 0.742534
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 1.51, NNZs: 2, Bias: -0.187964, T: 216000, Avg. loss: 0.746797
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 1.33, NNZs: 2, Bias: -0.504274, T: 224000, Avg. loss: 0.745385
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 1.08, NNZs: 2, Bias: -0.498236, T: 232000, Avg. loss: 0.746954
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 1.24, NNZs: 2, Bias: -0.202366, T: 240000, Avg. loss: 0.736160
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 1.19, NNZs: 2, Bias: -0.327170, T: 248000, Avg. loss: 0.741586
# Total training time: 0.01 seconds.
# -- Epoch 32
# Norm: 1.54, NNZs: 2, Bias: -0.365884, T: 256000, Avg. loss: 0.735320
# Total training time: 0.01 seconds.
# -- Epoch 33
# Norm: 1.18, NNZs: 2, Bias: -0.213078, T: 264000, Avg. loss: 0.737185
# Total training time: 0.01 seconds.
# -- Epoch 34
# Norm: 1.50, NNZs: 2, Bias: -0.436046, T: 272000, Avg. loss: 0.733395
# Total training time: 0.01 seconds.
# -- Epoch 35
# Norm: 1.36, NNZs: 2, Bias: -0.290815, T: 280000, Avg. loss: 0.739469
# Total training time: 0.01 seconds.
# -- Epoch 36
# Norm: 1.12, NNZs: 2, Bias: -0.465053, T: 288000, Avg. loss: 0.730228
# Total training time: 0.01 seconds.
# -- Epoch 37
# Norm: 1.67, NNZs: 2, Bias: -0.225788, T: 296000, Avg. loss: 0.729706
# Total training time: 0.01 seconds.
# -- Epoch 38
# Norm: 1.10, NNZs: 2, Bias: -0.294085, T: 304000, Avg. loss: 0.737088
# Total training time: 0.01 seconds.
# -- Epoch 39
# Norm: 1.28, NNZs: 2, Bias: -0.359583, T: 312000, Avg. loss: 0.731473
# Total training time: 0.02 seconds.
# -- Epoch 40
# Norm: 1.45, NNZs: 2, Bias: -0.421030, T: 320000, Avg. loss: 0.726306
# Total training time: 0.02 seconds.
# -- Epoch 41
# Norm: 1.27, NNZs: 2, Bias: -0.267194, T: 328000, Avg. loss: 0.730082
# Total training time: 0.02 seconds.
# -- Epoch 42
# Norm: 1.34, NNZs: 2, Bias: -0.358262, T: 336000, Avg. loss: 0.727296
# Total training time: 0.02 seconds.
# -- Epoch 43
# Norm: 1.33, NNZs: 2, Bias: -0.415595, T: 344000, Avg. loss: 0.728342
# Total training time: 0.02 seconds.
# -- Epoch 44
# Norm: 1.26, NNZs: 2, Bias: -0.215829, T: 352000, Avg. loss: 0.727837
# Total training time: 0.02 seconds.
# -- Epoch 45
# Norm: 1.46, NNZs: 2, Bias: -0.412341, T: 360000, Avg. loss: 0.726279
# Total training time: 0.02 seconds.
# Convergence after 45 epochs took 0.02 seconds
# -- Epoch 1
# Norm: 7.46, NNZs: 2, Bias: 2.285426, T: 8000, Avg. loss: 3.038118
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 4.36, NNZs: 2, Bias: 1.070444, T: 16000, Avg. loss: 1.202162
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 3.43, NNZs: 2, Bias: 1.483642, T: 24000, Avg. loss: 0.920630
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 3.15, NNZs: 2, Bias: -0.130202, T: 32000, Avg. loss: 0.813033
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 3.51, NNZs: 2, Bias: 0.601757, T: 40000, Avg. loss: 0.751213
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2.49, NNZs: 2, Bias: 0.083948, T: 48000, Avg. loss: 0.708562
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 3.28, NNZs: 2, Bias: -0.288874, T: 56000, Avg. loss: 0.679816
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 2.89, NNZs: 2, Bias: -0.568869, T: 64000, Avg. loss: 0.661138
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 2.60, NNZs: 2, Bias: -0.512699, T: 72000, Avg. loss: 0.640669
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 2.21, NNZs: 2, Bias: 0.148737, T: 80000, Avg. loss: 0.633149
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 2.85, NNZs: 2, Bias: 0.016757, T: 88000, Avg. loss: 0.625700
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 2.22, NNZs: 2, Bias: 0.731898, T: 96000, Avg. loss: 0.615984
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 2.66, NNZs: 2, Bias: 0.004464, T: 104000, Avg. loss: 0.608650
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 2.50, NNZs: 2, Bias: -0.442039, T: 112000, Avg. loss: 0.605523
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 2.15, NNZs: 2, Bias: -0.581529, T: 120000, Avg. loss: 0.592578
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 1.87, NNZs: 2, Bias: -0.161109, T: 128000, Avg. loss: 0.592241
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 2.23, NNZs: 2, Bias: -0.226798, T: 136000, Avg. loss: 0.588822
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 2.40, NNZs: 2, Bias: -0.353820, T: 144000, Avg. loss: 0.585426
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 2.26, NNZs: 2, Bias: -0.468024, T: 152000, Avg. loss: 0.583300
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 2.27, NNZs: 2, Bias: -0.199203, T: 160000, Avg. loss: 0.580274
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 2.54, NNZs: 2, Bias: 0.044671, T: 168000, Avg. loss: 0.576407
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 2.34, NNZs: 2, Bias: 0.040288, T: 176000, Avg. loss: 0.577218
# Total training time: 0.01 seconds.
# -- Epoch 23
# Norm: 2.32, NNZs: 2, Bias: -0.071767, T: 184000, Avg. loss: 0.570690
# Total training time: 0.01 seconds.
# -- Epoch 24
# Norm: 2.34, NNZs: 2, Bias: -0.225884, T: 192000, Avg. loss: 0.572026
# Total training time: 0.01 seconds.
# -- Epoch 25
# Norm: 2.34, NNZs: 2, Bias: 0.079850, T: 200000, Avg. loss: 0.569437
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 1.93, NNZs: 2, Bias: -0.019581, T: 208000, Avg. loss: 0.568546
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 1.77, NNZs: 2, Bias: -0.157846, T: 216000, Avg. loss: 0.566337
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 2.32, NNZs: 2, Bias: 0.156701, T: 224000, Avg. loss: 0.568244
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 2.20, NNZs: 2, Bias: 0.193168, T: 232000, Avg. loss: 0.565907
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 2.19, NNZs: 2, Bias: -0.021427, T: 240000, Avg. loss: 0.568675
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 1.72, NNZs: 2, Bias: -0.141529, T: 248000, Avg. loss: 0.563637
# Total training time: 0.01 seconds.
# -- Epoch 32
# Norm: 2.04, NNZs: 2, Bias: -0.138325, T: 256000, Avg. loss: 0.563492
# Total training time: 0.01 seconds.
# -- Epoch 33
# Norm: 1.95, NNZs: 2, Bias: -0.210311, T: 264000, Avg. loss: 0.562707
# Total training time: 0.01 seconds.
# -- Epoch 34
# Norm: 2.19, NNZs: 2, Bias: -0.022051, T: 272000, Avg. loss: 0.560176
# Total training time: 0.01 seconds.
# -- Epoch 35
# Norm: 2.13, NNZs: 2, Bias: -0.164468, T: 280000, Avg. loss: 0.559438
# Total training time: 0.01 seconds.
# -- Epoch 36
# Norm: 2.00, NNZs: 2, Bias: 0.012226, T: 288000, Avg. loss: 0.558722
# Total training time: 0.02 seconds.
# -- Epoch 37
# Norm: 1.84, NNZs: 2, Bias: 0.011189, T: 296000, Avg. loss: 0.561286
# Total training time: 0.02 seconds.
# -- Epoch 38
# Norm: 2.00, NNZs: 2, Bias: 0.173929, T: 304000, Avg. loss: 0.560055
# Total training time: 0.02 seconds.
# -- Epoch 39
# Norm: 1.87, NNZs: 2, Bias: 0.040678, T: 312000, Avg. loss: 0.555139
# Total training time: 0.02 seconds.
# -- Epoch 40
# Norm: 2.02, NNZs: 2, Bias: 0.070097, T: 320000, Avg. loss: 0.558802
# Total training time: 0.02 seconds.
# -- Epoch 41
# Norm: 1.96, NNZs: 2, Bias: 0.037541, T: 328000, Avg. loss: 0.557515
# Total training time: 0.02 seconds.
# -- Epoch 42
# Norm: 2.09, NNZs: 2, Bias: 0.095200, T: 336000, Avg. loss: 0.555708
# Total training time: 0.02 seconds.
# -- Epoch 43
# Norm: 2.24, NNZs: 2, Bias: -0.023529, T: 344000, Avg. loss: 0.554279
# Total training time: 0.02 seconds.
# -- Epoch 44
# Norm: 2.36, NNZs: 2, Bias: -0.165182, T: 352000, Avg. loss: 0.554901
# Total training time: 0.02 seconds.
# Convergence after 44 epochs took 0.02 seconds
# -- Epoch 1
# Norm: 8.83, NNZs: 2, Bias: -11.896592, T: 8000, Avg. loss: 1.386847
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 3.20, NNZs: 2, Bias: -5.448950, T: 16000, Avg. loss: 0.480409
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 1.69, NNZs: 2, Bias: -7.072883, T: 24000, Avg. loss: 0.345828
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 1.65, NNZs: 2, Bias: -5.536527, T: 32000, Avg. loss: 0.295751
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 1.80, NNZs: 2, Bias: -5.145814, T: 40000, Avg. loss: 0.265703
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2.48, NNZs: 2, Bias: -4.013729, T: 48000, Avg. loss: 0.229535
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.86, NNZs: 2, Bias: -4.209126, T: 56000, Avg. loss: 0.221999
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 1.53, NNZs: 2, Bias: -3.551404, T: 64000, Avg. loss: 0.210259
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 1.48, NNZs: 2, Bias: -3.830704, T: 72000, Avg. loss: 0.201428
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 1.29, NNZs: 2, Bias: -3.318849, T: 80000, Avg. loss: 0.192928
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 2.14, NNZs: 2, Bias: -3.222220, T: 88000, Avg. loss: 0.191219
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 1.10, NNZs: 2, Bias: -3.547945, T: 96000, Avg. loss: 0.184583
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 1.41, NNZs: 2, Bias: -2.765952, T: 104000, Avg. loss: 0.178859
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 1.39, NNZs: 2, Bias: -3.152368, T: 112000, Avg. loss: 0.178814
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 1.48, NNZs: 2, Bias: -3.072452, T: 120000, Avg. loss: 0.177067
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.77, NNZs: 2, Bias: -3.384066, T: 128000, Avg. loss: 0.175708
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 1.73, NNZs: 2, Bias: -2.644554, T: 136000, Avg. loss: 0.175516
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 1.26, NNZs: 2, Bias: -3.074667, T: 144000, Avg. loss: 0.169613
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 1.21, NNZs: 2, Bias: -3.461919, T: 152000, Avg. loss: 0.169239
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 1.33, NNZs: 2, Bias: -3.440452, T: 160000, Avg. loss: 0.168931
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 0.94, NNZs: 2, Bias: -3.073537, T: 168000, Avg. loss: 0.167928
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 1.12, NNZs: 2, Bias: -2.840758, T: 176000, Avg. loss: 0.167491
# Total training time: 0.01 seconds.
# -- Epoch 23
# Norm: 1.44, NNZs: 2, Bias: -2.900289, T: 184000, Avg. loss: 0.165720
# Total training time: 0.01 seconds.
# -- Epoch 24
# Norm: 1.14, NNZs: 2, Bias: -2.696448, T: 192000, Avg. loss: 0.163732
# Total training time: 0.01 seconds.
# -- Epoch 25
# Norm: 1.30, NNZs: 2, Bias: -2.752342, T: 200000, Avg. loss: 0.164993
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 1.32, NNZs: 2, Bias: -2.849217, T: 208000, Avg. loss: 0.163315
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 1.30, NNZs: 2, Bias: -2.573435, T: 216000, Avg. loss: 0.160863
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 1.20, NNZs: 2, Bias: -2.894589, T: 224000, Avg. loss: 0.163072
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 1.34, NNZs: 2, Bias: -2.679113, T: 232000, Avg. loss: 0.161197
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 1.58, NNZs: 2, Bias: -2.769097, T: 240000, Avg. loss: 0.158702
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 1.39, NNZs: 2, Bias: -2.892237, T: 248000, Avg. loss: 0.157711
# Total training time: 0.01 seconds.
# -- Epoch 32
# Norm: 1.21, NNZs: 2, Bias: -2.894996, T: 256000, Avg. loss: 0.158250
# Total training time: 0.01 seconds.
# -- Epoch 33
# Norm: 1.19, NNZs: 2, Bias: -2.968663, T: 264000, Avg. loss: 0.159089
# Total training time: 0.01 seconds.
# -- Epoch 34
# Norm: 1.65, NNZs: 2, Bias: -2.745882, T: 272000, Avg. loss: 0.155685
# Total training time: 0.01 seconds.
# -- Epoch 35
# Norm: 1.50, NNZs: 2, Bias: -2.854110, T: 280000, Avg. loss: 0.155395
# Total training time: 0.01 seconds.
# -- Epoch 36
# Norm: 1.79, NNZs: 2, Bias: -2.648613, T: 288000, Avg. loss: 0.156382
# Total training time: 0.01 seconds.
# -- Epoch 37
# Norm: 1.14, NNZs: 2, Bias: -2.855681, T: 296000, Avg. loss: 0.157343
# Total training time: 0.01 seconds.
# -- Epoch 38
# Norm: 1.34, NNZs: 2, Bias: -2.790156, T: 304000, Avg. loss: 0.154332
# Total training time: 0.01 seconds.
# -- Epoch 39
# Norm: 1.50, NNZs: 2, Bias: -2.600078, T: 312000, Avg. loss: 0.154839
# Total training time: 0.01 seconds.
# -- Epoch 40
# Norm: 1.26, NNZs: 2, Bias: -2.666357, T: 320000, Avg. loss: 0.154067
# Total training time: 0.01 seconds.
# -- Epoch 41
# Norm: 1.26, NNZs: 2, Bias: -2.821011, T: 328000, Avg. loss: 0.153724
# Total training time: 0.01 seconds.
# -- Epoch 42
# Norm: 1.29, NNZs: 2, Bias: -2.850405, T: 336000, Avg. loss: 0.155264
# Total training time: 0.01 seconds.
# -- Epoch 43
# Norm: 1.11, NNZs: 2, Bias: -2.705574, T: 344000, Avg. loss: 0.153454
# Total training time: 0.01 seconds.
# Convergence after 43 epochs took 0.01 seconds

# %%
hue_labels = le.inverse_transform(y_test) if hasattr(le, "classes_") else y_test
sns.scatterplot(x=X_test_pca[:, 0], y=X_test_pca[:, 1], hue=hue_labels, alpha=0.6)
plt.title("PCA Projection of Data with SVM Predictions")
plt.show()

# %%
# Get feature importance in PCA
components_df = pd.DataFrame(pca.components_, columns=X_train.columns, index=[f'PC{i+1}' for i in range(pca.n_components_)])

# Plot the contributions of original features to the first two principal components
plt.figure(figsize=(10, 6))
sns.heatmap(components_df, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
plt.title("Feature Contributions to Principal Components")
plt.xlabel("Original Features")
plt.ylabel("Principal Components")
plt.show()

# %%
pca_full = PCA().fit(X_train_scaled)
cumulative_variance = np.cumsum(pca_full.explained_variance_ratio_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--', color='teal')
plt.axhline(y=0.95, color='r', linestyle='-')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Number of Components Needed for 95% Variance")
plt.show()

# Print the number of components required for 95% variance
n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Number of principal components required for 95% variance: {n_components_95}")
# Out:
# Number of principal components required for 95% variance: 2

# %%
# Get explained variance ratio
explained_variance = pca.explained_variance_ratio_

# Plot explained variance
plt.figure(figsize=(8, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance * 100, color='teal', alpha=0.7)
plt.xlabel("Principal Component")
plt.ylabel("Variance Explained (%)")
plt.title("Explained Variance by Principal Components")
plt.show()

# %%
# Evaluate PCA-based SVM
print("\nSVM with PCA Classification Report:")
print(classification_report(y_test, y_pred_pca, target_names=['star', 'galaxy', 'qso']))

# Train SVM on full dataset (without PCA) for comparison
svm_model_full = SGDClassifier(loss='hinge', max_iter=10000, tol=1e-3, random_state=100)
svm_model_full.fit(X_train_scaled, y_train)
y_pred_full = svm_model_full.predict(X_test_scaled)

# Evaluate SVM without PCA
print("\nSVM without PCA Classification Report:")
print(classification_report(y_test, y_pred_full, target_names=['star', 'galaxy', 'qso']))
# Out:
# SVM with PCA Classification Report:
#               precision    recall  f1-score   support
#
#         star       0.61      0.70      0.65       832
#       galaxy       0.76      0.80      0.78       999
#          qso       0.00      0.00      0.00       169
#
#     accuracy                           0.69      2000
#    macro avg       0.46      0.50      0.48      2000
# weighted avg       0.64      0.69      0.66      2000
#
#
# SVM without PCA Classification Report:
#               precision    recall  f1-score   support
#
#         star       0.88      0.96      0.92       832
#       galaxy       0.95      0.92      0.94       999
#          qso       0.96      0.71      0.82       169
#
#     accuracy                           0.92      2000
#    macro avg       0.93      0.86      0.89      2000
# weighted avg       0.92      0.92      0.92      2000
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
